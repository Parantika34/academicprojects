# %%
import numpy as np

# %%
import pandas as pd
import seaborn as sns #importing our visualization library
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('netflix_titles.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
 df.isnull().sum() #checking for null values
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df.drop(['director','cast'],axis = 1,inplace = True)

# %%
df['country'].replace(np.nan, 'United States',inplace  = True)

# %%
df.drop(['date_added'],axis =1,inplace = True)

# %%
df['rating'].value_counts(dropna=False)
# Out:
# TV-MA       2027
# TV-14       1698
# TV-PG        701
# R            508
# PG-13        286
# NR           218
# PG           184
# TV-Y7        169
# TV-G         149
# TV-Y         143
# TV-Y7-FV      95
# G             37
# NaN           10
# UR             7
# NC-17          2
# Name: rating, dtype: int64

# %%
#df['rating'].replace(np.nan, 'TV-MA',inplace  = True)

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# country          0
# release_year     0
# rating          10
# duration         0
# listed_in        0
# description      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (5,2))
color = ["dusty purple"]
sns.countplot(
    y='type',
    data = df,
    order = df['type'].value_counts(ascending=True).index,
    palette = sns.xkcd_palette(color))
sns.despine(bottom = True, left = True)

# %%
plt.figure(figsize = (8,4))
color = ["windows blue"]
sns.countplot(y='rating',
              data = df,
              hue=None,
              order = df['rating'].value_counts(ascending=True).index,
              palette = sns.xkcd_palette(color))
sns.despine(bottom = True, left = True)

# %%
df["release_year"][df["type"]=="Movie"].value_counts().sort_index(ascending=False)
# Out:
# 2020      6
# 2019    400
# 2018    646
# 2017    682
# 2016    593
#        ...
# 1946      2
# 1945      3
# 1944      3
# 1943      3
# 1942      2
# Name: release_year, Length: 70, dtype: int64

# %%
plt.figure(figsize=(8,4))
df["release_year"][df["type"]=="Movie"].value_counts()[:20].sort_index().plot(kind="bar",color="pink")
plt.title("Frequency of Movies released in different years on Netflix")
sns.despine(bottom = True, left = True)
# Out:
# C:\Users\paran\AppData\Local\Temp\ipykernel_9232\4252813616.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df["release_year"][df["type"]=="Movie"].value_counts()[:20].sort_index().plot(kind="bar",color="pink")

# %%
plt.figure(figsize=(8,4))
df[df["type"]=="TV Show"]["release_year"].value_counts()[:20].sort_index().plot(kind="bar",color="Blue")
plt.title("Frequency of TV shows which were released in different years and are available on Netflix")
sns.despine(bottom = True, left = True)
# Out:
# C:\Users\paran\AppData\Local\Temp\ipykernel_9232\3566529336.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df[df["type"]=="TV Show"]["release_year"].value_counts()[:20].sort_index().plot(kind="bar",color="Blue")

# %%
plt.figure(figsize=(6,4))
df[df["type"]=="TV Show"]["listed_in"].value_counts()[:5].plot(kind="barh",color="grey")
plt.title("Top 5 Genres in TV Shows",size=18)
sns.despine(bottom = True, left = True)

# %%
plt.figure(figsize=(6,4))
df[df["type"]=="Movie"]["listed_in"].value_counts()[:5].plot(kind="barh",color="grey")
plt.title("Top 5 Genres in Movies",size=10)
sns.despine(bottom = True, left = True)
